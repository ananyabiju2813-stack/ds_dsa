# %%
from sklearn.tree import DecisionTreeClassifier

# %%
import pandas as pd

# %%
data = pd.DataFrame({
    'x': [[20,3002],[25,2656],[30,5000],[35,6000],[32,4879]],
    'y': ['yes','no','yes','yes','no']
})

print(data)
# Out:
#             x    y
# 0  [20, 3002]  yes
# 1  [25, 2656]   no
# 2  [30, 5000]  yes
# 3  [35, 6000]  yes
# 4  [32, 4879]   no
