# %%
print("Hello")
# Out:
# Hello

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
data=pd.read_csv("tip.csv")

# %%
data
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# list operations

# %%
l1=list()

# %%
type(l1)
# Out:
# list

# %%
l1.append(10)

# %%
l1
# Out:
# [10]

# %%
l1.append(2)

# %%
l1.append(30)

# %%
l1.append(23)

# %%
l1
# Out:
# [10, 2, 30, 23]

# %%
l1[-2]
# Out:
# 30

# %%
l1.sort()

# %%
l1
# Out:
# [2, 10, 23, 30]

# %%
num=[2,5,1,10,8,23,21,11]

# %%
nums=sorted(num)

# %%
nums
# Out:
# [1, 2, 5, 8, 10, 11, 21, 23]

# %%
names=['doe','shark','binu']

# %%
names
# Out:
# ['doe', 'shark', 'binu']

# %%
snames=sorted(names)

# %%
snames
# Out:
# ['binu', 'doe', 'shark']

# %%
#sort name based on length

# %%
lnames=sorted(names,key=len)

# %%
lnames
# Out:
# ['doe', 'binu', 'shark']

# %%
lnames=sorted(names,key=len,reverse=True)

# %%
lnames
# Out:
# ['shark', 'binu', 'doe']

# %%
lnum=[0] + [2**i for i in range(0,11)]

# %%
lnum
# Out:
# [0, 1, 2, 4, 8, 16, 32, 64, 128, 256, 512, 1024]

# %%
lnum=[i for i in range(1,11) if i % 2!=0]

# %%
lnum
# Out:
# [1, 3, 5, 7, 9]

# %%
lm= [1,2,3,4,2,5,9]

# %%
lm= list(set(lm))

print(lm)
# Out:
# [1, 2, 3, 4, 5, 9]

# %%
rev=[2,3,4,1,5,9]

# %%
rev = [2, 3, 4, 1, 5, 9]

for i in range(len(rev)-1, -1, -1):
    print(rev[i], end=" ")
# Out:
# 9 5 1 4 3 2

# %%
d={'a':100,'b':200,'c':300}

# %%
d.get('a')
# Out:
# 100

# %%
d.get('d',0)
# Out:
# 0

# %%
d.popitem()
# Out:
# ('c', 300)

# %%
d.pop('a')
# Out:
# 100

# %%
d
# Out:
# {'b': 200}

# %%
emp={'id':1000,'name':'joe','salary':150000}

# %%
emp
# Out:
# {'id': 1000, 'name': 'joe', 'salary': 150000}

# %%
emp.setdefault('palace','goa')
# Out:
# 'goa'

# %%
emp
# Out:
# {'id': 1000,
#  'name': 'joe',
#  'salary': 150000,
#  'ipalace': 'goa',
#  'palace': 'goa'}

# %%
emp.items()
# Out:
# dict_items([('id', 1000), ('name', 'joe'), ('salary', 150000), ('ipalace', 'goa'), ('palace', 'goa')])

# %%
#()

# %%
t1=(1,2,3,4)

# %%
t1[0]
# Out:
# 1

# %%
t1[0]=100
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[110], line 1
# ----> 1 t1[0]=100
#
# TypeError: 'tuple' object does not support item assignment

# %%
t2=([1,2,3,],[2,4,5])

# %%
t2[1][2]=3

# %%
#set

# %%
s1={1,2,3,3,4,5}

# %%
s1
# Out:
# {1, 2, 3, 4, 5}

# %%
ls=[1,2,3,3,4,4,5]

# %%
ls=set(ls)

# %%
ls
# Out:
# {1, 2, 3, 4, 5}

# %%
s1={1,2,3,4,5,3,3773,66,4444}

# %%
s1
# Out:
# {1, 2, 3, 4, 5, 66, 3773, 4444}
